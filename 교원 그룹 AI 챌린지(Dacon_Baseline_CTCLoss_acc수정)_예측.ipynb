# %%
# !pip install pytorch_lightning
# !pip install timm
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.8.6-py3-none-any.whl (800 kB)
#      |████████████████████████████████| 800 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.21.6)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 87.9 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.4.0)
# Collecting lightning-utilities!=0.4.0,>=0.3.0
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (2022.11.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.64.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.13.0+cu116)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      |████████████████████████████████| 512 kB 74.0 MB/s
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.23.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.9)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX>=2.2->pytorch_lightning) (3.19.6)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.0.4)
# Installing collected packages: torchmetrics, tensorboardX, lightning-utilities, pytorch-lightning
# Successfully installed lightning-utilities-0.5.0 pytorch-lightning-1.8.6 tensorboardX-2.5.1 torchmetrics-0.11.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      |████████████████████████████████| 549 kB 5.0 MB/s
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.8/dist-packages (from timm) (1.13.0+cu116)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 62.8 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from timm) (0.14.0+cu116)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from timm) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.7->timm) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (3.8.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub->timm) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (3.0.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision->timm) (1.21.6)
# Installing collected packages: huggingface-hub, timm
# Successfully installed huggingface-hub-0.11.1 timm-0.6.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 427 kB/s
# Installing collected packages: einops
# Successfully installed einops-0.6.0

# %% [markdown]
# ## 라이브러리 호출
#
# 학습에 필요한 라이브러리르 호출한다.

# %%
import timm
import random
import os

import pandas as pd
import numpy as np

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pytorch_lightning as pl

from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet18
from torchvision import transforms

import albumentations as A
import albumentations.pytorch

from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

from einops import rearrange, reduce, repeat

import gc

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 구글 드라이브 연결
#
# 구글 코랩에서 학습을 수행하기 위해서는 기본적으로 코랩에 연결시켜야 한다. 아래와 같이 수행하면 된다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/datasets/open.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: train/TRAIN_71888.png
#   inflating: train/TRAIN_71889.png
#   inflating: train/TRAIN_71890.png
#   inflating: train/TRAIN_71891.png
#   inflating: train/TRAIN_71892.png
#   inflating: train/TRAIN_71893.png
#   inflating: train/TRAIN_71894.png
#   inflating: train/TRAIN_71895.png
#   inflating: train/TRAIN_71896.png
#   inflating: train/TRAIN_71897.png
#   inflating: train/TRAIN_71898.png
#   inflating: train/TRAIN_71899.png
#   inflating: train/TRAIN_71900.png
#   inflating: train/TRAIN_71901.png
#   inflating: train/TRAIN_71902.png
#   inflating: train/TRAIN_71903.png
#   inflating: train/TRAIN_71904.png
#   inflating: train/TRAIN_71905.png
#   inflating: train/TRAIN_71906.png
#   inflating: train/TRAIN_71907.png
#   inflating: train/TRAIN_71908.png
#   inflating: train/TRAIN_71909.png
#   inflating: train/TRAIN_71910.png
#   inflating: train/TRAIN_71911.png
#   inflating: train/TRAIN_71912.png
#   inflating: train/TRAIN_71913.png
#   inflating: train/TRAIN_71914.png
#   inflating: train/TRAIN_71915.png
#   inflating: train/TRAIN_71916.png
#   inflating: train/TRAIN_71917.png
#   inflating: train/TRAIN_71918.png
#   inflating: train/TRAIN_71919.png
#   inflating: train/TRAIN_71920.png
#   inflating: train/TRAIN_71921.png
#   inflating: train/TRAIN_71922.png
#   inflating: train/TRAIN_71923.png
#   inflating: train/TRAIN_71924.png
#   inflating: train/TRAIN_71925.png
#   inflating: train/TRAIN_71926.png
#   inflating: train/TRAIN_71927.png
#   inflating: train/TRAIN_71928.png
#   inflating: train/TRAIN_71929.png
#   inflating: train/TRAIN_71930.png
#   inflating: train/TRAIN_71931.png
#   inflating: train/TRAIN_71932.png
#   inflating: train/TRAIN_71933.png
#   inflating: train/TRAIN_71934.png
#   inflating: train/TRAIN_71935.png
#   inflating: train/TRAIN_71936.png
#   inflating: train/TRAIN_71937.png
#   inflating: train/TRAIN_71938.png
#   inflating: train/TRAIN_71939.png
#   inflating: train/TRAIN_71940.png
#   inflating: train/TRAIN_71941.png
#   inflating: train/TRAIN_71942.png
#   inflating: train/TRAIN_71943.png
#   inflating: train/TRAIN_71944.png
#   inflating: train/TRAIN_71945.png
#   inflating: train/TRAIN_71946.png
#   inflating: train/TRAIN_71947.png
#   inflating: train/TRAIN_71948.png
#   inflating: train/TRAIN_71949.png
#   inflating: train/TRAIN_71950.png
#   inflating: train/TRAIN_71951.png
#   inflating: train/TRAIN_71952.png
#   inflating: train/TRAIN_71953.png
#   inflating: train/TRAIN_71954.png
#   inflating: train/TRAIN_71955.png
#   inflating: train/TRAIN_71956.png
#   inflating: train/TRAIN_71957.png
#   inflating: train/TRAIN_71958.png
#   inflating: train/TRAIN_71959.png
#   inflating: train/TRAIN_71960.png
#   inflating: train/TRAIN_71961.png
#   inflating: train/TRAIN_71962.png
#   inflating: train/TRAIN_71963.png
#   inflating: train/TRAIN_71964.png
#   inflating: train/TRAIN_71965.png
#   inflating: train/TRAIN_71966.png
#   inflating: train/TRAIN_71967.png
#   inflating: train/TRAIN_71968.png
#   inflating: train/TRAIN_71969.png
#   inflating: train/TRAIN_71970.png
#   inflating: train/TRAIN_71971.png
#   inflating: train/TRAIN_71972.png
#   inflating: train/TRAIN_71973.png
#   inflating: train/TRAIN_71974.png
#   inflating: train/TRAIN_71975.png
#   inflating: train/TRAIN_71976.png
#   inflating: train/TRAIN_71977.png
#   inflating: train/TRAIN_71978.png
#   inflating: train/TRAIN_71979.png
#   inflating: train/TRAIN_71980.png
#   inflating: train/TRAIN_71981.png
#   inflating: train/TRAIN_71982.png
#   inflating: train/TRAIN_71983.png
#   inflating: train/TRAIN_71984.png
#   inflating: train/TRAIN_71985.png
#   inflating: train/TRAIN_71986.png
#   inflating: train/TRAIN_71987.png
#   inflating: train/TRAIN_71988.png
#   inflating: train/TRAIN_71989.png
#   inflating: train/TRAIN_71990.png
#   inflating: train/TRAIN_71991.png
#   inflating: train/TRAIN_71992.png
#   inflating: train/TRAIN_71993.png
#   inflating: train/TRAIN_71994.png
#   inflating: train/TRAIN_71995.png
#   inflating: train/TRAIN_71996.png
#   inflating: train/TRAIN_71997.png
#   inflating: train/TRAIN_71998.png
#   inflating: train/TRAIN_71999.png
#   inflating: train/TRAIN_72000.png
#   inflating: train/TRAIN_72001.png
#   inflating: train/TRAIN_72002.png
#   inflating: train/TRAIN_72003.png
#   inflating: train/TRAIN_72004.png
#   inflating: train/TRAIN_72005.png
#   inflating: train/TRAIN_72006.png
#   inflating: train/TRAIN_72007.png
#   inflating: train/TRAIN_72008.png
#   inflating: train/TRAIN_72009.png
#   inflating: train/TRAIN_72010.png
#   inflating: train/TRAIN_72011.png
#   inflating: train/TRAIN_72012.png
#   inflating: train/TRAIN_72013.png
#   inflating: train/TRAIN_72014.png
#   inflating: train/TRAIN_72015.png
#   inflating: train/TRAIN_72016.png
#   inflating: train/TRAIN_72017.png
#   inflating: train/TRAIN_72018.png
#   inflating: train/TRAIN_72019.png
#   inflating: train/TRAIN_72020.png
#   inflating: train/TRAIN_72021.png
#   inflating: train/TRAIN_72022.png
#   inflating: train/TRAIN_72023.png
#   inflating: train/TRAIN_72024.png
#   inflating: train/TRAIN_72025.png
#   inflating: train/TRAIN_72026.png
#   inflating: train/TRAIN_72027.png
#   inflating: train/TRAIN_72028.png
#   inflating: train/TRAIN_72029.png
#   inflating: train/TRAIN_72030.png
#   inflating: train/TRAIN_72031.png
#   inflating: train/TRAIN_72032.png
#   inflating: train/TRAIN_72033.png
#   inflating: train/TRAIN_72034.png
#   inflating: train/TRAIN_72035.png
#   inflating: train/TRAIN_72036.png
#   inflating: train/TRAIN_72037.png
#   inflating: train/TRAIN_72038.png
#   inflating: train/TRAIN_72039.png
#   inflating: train/TRAIN_72040.png
#   inflating: train/TRAIN_72041.png
#   inflating: train/TRAIN_72042.png
#   inflating: train/TRAIN_72043.png
#   inflating: train/TRAIN_72044.png
#   inflating: train/TRAIN_72045.png
#   inflating: train/TRAIN_72046.png
#   inflating: train/TRAIN_72047.png
#   inflating: train/TRAIN_72048.png
#   inflating: train/TRAIN_72049.png
#   inflating: train/TRAIN_72050.png
#   inflating: train/TRAIN_72051.png
#   inflating: train/TRAIN_72052.png
#   inflating: train/TRAIN_72053.png
#   inflating: train/TRAIN_72054.png
#   inflating: train/TRAIN_72055.png
#   inflating: train/TRAIN_72056.png
#   inflating: train/TRAIN_72057.png
#   inflating: train/TRAIN_72058.png
#   inflating: train/TRAIN_72059.png
#   inflating: train/TRAIN_72060.png
#   inflating: train/TRAIN_72061.png
#   inflating: train/TRAIN_72062.png
#   inflating: train/TRAIN_72063.png
#   inflating: train/TRAIN_72064.png
#   inflating: train/TRAIN_72065.png
#   inflating: train/TRAIN_72066.png
#   inflating: train/TRAIN_72067.png
#   inflating: train/TRAIN_72068.png
#   inflating: train/TRAIN_72069.png
#   inflating: train/TRAIN_72070.png
#   inflating: train/TRAIN_72071.png
#   inflating: train/TRAIN_72072.png
#   inflating: train/TRAIN_72073.png
#   inflating: train/TRAIN_72074.png
#   inflating: train/TRAIN_72075.png
#   inflating: train/TRAIN_72076.png
#   inflating: train/TRAIN_72077.png
#   inflating: train/TRAIN_72078.png
#   inflating: train/TRAIN_72079.png
#   inflating: train/TRAIN_72080.png
#   inflating: train/TRAIN_72081.png
#   inflating: train/TRAIN_72082.png
#   inflating: train/TRAIN_72083.png
#   inflating: train/TRAIN_72084.png
#   inflating: train/TRAIN_72085.png
#   inflating: train/TRAIN_72086.png
#   inflating: train/TRAIN_72087.png
#   inflating: train/TRAIN_72088.png
#   inflating: train/TRAIN_72089.png
#   inflating: train/TRAIN_72090.png
#   inflating: train/TRAIN_72091.png
#   inflating: train/TRAIN_72092.png
#   inflating: train/TRAIN_72093.png
#   inflating: train/TRAIN_72094.png
#   inflating: train/TRAIN_72095.png
#   inflating: train/TRAIN_72096.png
#   inflating: train/TRAIN_72097.png
#   inflating: train/TRAIN_72098.png
#   inflating: train/TRAIN_72099.png
#   inflating: train/TRAIN_72100.png
#   inflating: train/TRAIN_72101.png
#   inflating: train/TRAIN_72102.png
#   inflating: train/TRAIN_72103.png
#   inflating: train/TRAIN_72104.png
#   inflating: train/TRAIN_72105.png
#   inflating: train/TRAIN_72106.png
#   inflating: train/TRAIN_72107.png
#   inflating: train/TRAIN_72108.png
#   inflating: train/TRAIN_72109.png
#   inflating: train/TRAIN_72110.png
#   inflating: train/TRAIN_72111.png
#   inflating: train/TRAIN_72112.png
#   inflating: train/TRAIN_72113.png
#   inflating: train/TRAIN_72114.png
#   inflating: train/TRAIN_72115.png
#   inflating: train/TRAIN_72116.png
#   inflating: train/TRAIN_72117.png
#   inflating: train/TRAIN_72118.png
#   inflating: train/TRAIN_72119.png
#   inflating: train/TRAIN_72120.png
#   inflating: train/TRAIN_72121.png
#   inflating: train/TRAIN_72122.png
#   inflating: train/TRAIN_72123.png
#   inflating: train/TRAIN_72124.png
#   inflating: train/TRAIN_72125.png
#   inflating: train/TRAIN_72126.png
#   inflating: train/TRAIN_72127.png
#   inflating: train/TRAIN_72128.png
#   inflating: train/TRAIN_72129.png
#   inflating: train/TRAIN_72130.png
#   inflating: train/TRAIN_72131.png
#   inflating: train/TRAIN_72132.png
#   inflating: train/TRAIN_72133.png
#   inflating: train/TRAIN_72134.png
#   inflating: train/TRAIN_72135.png
#   inflating: train/TRAIN_72136.png
#   inflating: train/TRAIN_72137.png
#   inflating: train/TRAIN_72138.png
#   inflating: train/TRAIN_72139.png
#   inflating: train/TRAIN_72140.png
#   inflating: train/TRAIN_72141.png
#   inflating: train/TRAIN_72142.png
#   inflating: train/TRAIN_72143.png
#   inflating: train/TRAIN_72144.png
#   inflating: train/TRAIN_72145.png
#   inflating: train/TRAIN_72146.png
#   inflating: train/TRAIN_72147.png
#   inflating: train/TRAIN_72148.png
#   inflating: train/TRAIN_72149.png
#   inflating: train/TRAIN_72150.png
#   inflating: train/TRAIN_72151.png
#   inflating: train/TRAIN_72152.png
#   inflating: train/TRAIN_72153.png
#   inflating: train/TRAIN_72154.png
#   inflating: train/TRAIN_72155.png
#   inflating: train/TRAIN_72156.png
#   inflating: train/TRAIN_72157.png
#   inflating: train/TRAIN_72158.png
#   inflating: train/TRAIN_72159.png
#   inflating: train/TRAIN_72160.png
#   inflating: train/TRAIN_72161.png
#   inflating: train/TRAIN_72162.png
#   inflating: train/TRAIN_72163.png
#   inflating: train/TRAIN_72164.png
#   inflating: train/TRAIN_72165.png
#   inflating: train/TRAIN_72166.png
#   inflating: train/TRAIN_72167.png
#   inflating: train/TRAIN_72168.png
#   inflating: train/TRAIN_72169.png
#   inflating: train/TRAIN_72170.png
#   inflating: train/TRAIN_72171.png
#   inflating: train/TRAIN_72172.png
#   inflating: train/TRAIN_72173.png
#   inflating: train/TRAIN_72174.png
#   inflating: train/TRAIN_72175.png
#   inflating: train/TRAIN_72176.png
#   inflating: train/TRAIN_72177.png
#   inflating: train/TRAIN_72178.png
#   inflating: train/TRAIN_72179.png
#   inflating: train/TRAIN_72180.png
#   inflating: train/TRAIN_72181.png
#   inflating: train/TRAIN_72182.png
#   inflating: train/TRAIN_72183.png
#   inflating: train/TRAIN_72184.png
#   inflating: train/TRAIN_72185.png
#   inflating: train/TRAIN_72186.png
#   inflating: train/TRAIN_72187.png
#   inflating: train/TRAIN_72188.png
#   inflating: train/TRAIN_72189.png
#   inflating: train/TRAIN_72190.png
#   inflating: train/TRAIN_72191.png
#   inflating: train/TRAIN_72192.png
#   inflating: train/TRAIN_72193.png
#   inflating: train/TRAIN_72194.png
#   inflating: train/TRAIN_72195.png
#   inflating: train/TRAIN_72196.png
#   inflating: train/TRAIN_72197.png
#   inflating: train/TRAIN_72198.png
#   inflating: train/TRAIN_72199.png
#   inflating: train/TRAIN_72200.png
#   inflating: train/TRAIN_72201.png
#   inflating: train/TRAIN_72202.png
#   inflating: train/TRAIN_72203.png
#   inflating: train/TRAIN_72204.png
#   inflating: train/TRAIN_72205.png
#   inflating: train/TRAIN_72206.png
#   inflating: train/TRAIN_72207.png
#   inflating: train/TRAIN_72208.png
#   inflating: train/TRAIN_72209.png
#   inflating: train/TRAIN_72210.png
#   inflating: train/TRAIN_72211.png
#   inflating: train/TRAIN_72212.png
#   inflating: train/TRAIN_72213.png
#   inflating: train/TRAIN_72214.png
#   inflating: train/TRAIN_72215.png
#   inflating: train/TRAIN_72216.png
#   inflating: train/TRAIN_72217.png
#   inflating: train/TRAIN_72218.png
#   inflating: train/TRAIN_72219.png
#   inflating: train/TRAIN_72220.png
#   inflating: train/TRAIN_72221.png
#   inflating: train/TRAIN_72222.png
#   inflating: train/TRAIN_72223.png
#   inflating: train/TRAIN_72224.png
#   inflating: train/TRAIN_72225.png
#   inflating: train/TRAIN_72226.png
#   inflating: train/TRAIN_72227.png
#   inflating: train/TRAIN_72228.png
#   inflating: train/TRAIN_72229.png
#   inflating: train/TRAIN_72230.png
#   inflating: train/TRAIN_72231.png
#   inflating: train/TRAIN_72232.png
#   inflating: train/TRAIN_72233.png
#   inflating: train/TRAIN_72234.png
#   inflating: train/TRAIN_72235.png
#   inflating: train/TRAIN_72236.png
#   inflating: train/TRAIN_72237.png
#   inflating: train/TRAIN_72238.png
#   inflating: train/TRAIN_72239.png
#   inflating: train/TRAIN_72240.png
#   inflating: train/TRAIN_72241.png
#   inflating: train/TRAIN_72242.png
#   inflating: train/TRAIN_72243.png
#   inflating: train/TRAIN_72244.png
#   inflating: train/TRAIN_72245.png
#   inflating: train/TRAIN_72246.png
#   inflating: train/TRAIN_72247.png
#   inflating: train/TRAIN_72248.png
#   inflating: train/TRAIN_72249.png
#   inflating: train/TRAIN_72250.png
#   inflating: train/TRAIN_72251.png
#   inflating: train/TRAIN_72252.png
#   inflating: train/TRAIN_72253.png
#   inflating: train/TRAIN_72254.png
#   inflating: train/TRAIN_72255.png
#   inflating: train/TRAIN_72256.png
#   inflating: train/TRAIN_72257.png
#   inflating: train/TRAIN_72258.png
#   inflating: train/TRAIN_72259.png
#   inflating: train/TRAIN_72260.png
#   inflating: train/TRAIN_72261.png
#   inflating: train/TRAIN_72262.png
#   inflating: train/TRAIN_72263.png
#   inflating: train/TRAIN_72264.png
#   inflating: train/TRAIN_72265.png
#   inflating: train/TRAIN_72266.png
#   inflating: train/TRAIN_72267.png
#   inflating: train/TRAIN_72268.png
#   inflating: train/TRAIN_72269.png
#   inflating: train/TRAIN_72270.png
#   inflating: train/TRAIN_72271.png
#   inflating: train/TRAIN_72272.png
#   inflating: train/TRAIN_72273.png
#   inflating: train/TRAIN_72274.png
#   inflating: train/TRAIN_72275.png
#   inflating: train/TRAIN_72276.png
#   inflating: train/TRAIN_72277.png
#   inflating: train/TRAIN_72278.png
#   inflating: train/TRAIN_72279.png
#   inflating: train/TRAIN_72280.png
#   inflating: train/TRAIN_72281.png
#   inflating: train/TRAIN_72282.png
#   inflating: train/TRAIN_72283.png
#   inflating: train/TRAIN_72284.png
#   inflating: train/TRAIN_72285.png
#   inflating: train/TRAIN_72286.png
#   inflating: train/TRAIN_72287.png
#   inflating: train/TRAIN_72288.png
#   inflating: train/TRAIN_72289.png
#   inflating: train/TRAIN_72290.png
#   inflating: train/TRAIN_72291.png
#   inflating: train/TRAIN_72292.png
#   inflating: train/TRAIN_72293.png
#   inflating: train/TRAIN_72294.png
#   inflating: train/TRAIN_72295.png
#   inflating: train/TRAIN_72296.png
#   inflating: train/TRAIN_72297.png
#   inflating: train/TRAIN_72298.png
#   inflating: train/TRAIN_72299.png
#   inflating: train/TRAIN_72300.png
#   inflating: train/TRAIN_72301.png
#   inflating: train/TRAIN_72302.png
#   inflating: train/TRAIN_72303.png
#   inflating: train/TRAIN_72304.png
#   inflating: train/TRAIN_72305.png
#   inflating: train/TRAIN_72306.png
#   inflating: train/TRAIN_72307.png
#   inflating: train/TRAIN_72308.png
#   inflating: train/TRAIN_72309.png
#   inflating: train/TRAIN_72310.png
#   inflating: train/TRAIN_72311.png
#   inflating: train/TRAIN_72312.png
#   inflating: train/TRAIN_72313.png
#   inflating: train/TRAIN_72314.png
#   inflating: train/TRAIN_72315.png
#   inflating: train/TRAIN_72316.png
#   inflating: train/TRAIN_72317.png
#   inflating: train/TRAIN_72318.png
#   inflating: train/TRAIN_72319.png
#   inflating: train/TRAIN_72320.png
#   inflating: train/TRAIN_72321.png
#   inflating: train/TRAIN_72322.png
#   inflating: train/TRAIN_72323.png
#   inflating: train/TRAIN_72324.png
#   inflating: train/TRAIN_72325.png
#   inflating: train/TRAIN_72326.png
#   inflating: train/TRAIN_72327.png
#   inflating: train/TRAIN_72328.png
#   inflating: train/TRAIN_72329.png
#   inflating: train/TRAIN_72330.png
#   inflating: train/TRAIN_72331.png
#   inflating: train/TRAIN_72332.png
#   inflating: train/TRAIN_72333.png
#   inflating: train/TRAIN_72334.png
#   inflating: train/TRAIN_72335.png
#   inflating: train/TRAIN_72336.png
#   inflating: train/TRAIN_72337.png
#   inflating: train/TRAIN_72338.png
#   inflating: train/TRAIN_72339.png
#   inflating: train/TRAIN_72340.png
#   inflating: train/TRAIN_72341.png
#   inflating: train/TRAIN_72342.png
#   inflating: train/TRAIN_72343.png
#   inflating: train/TRAIN_72344.png
#   inflating: train/TRAIN_72345.png
#   inflating: train/TRAIN_72346.png
#   inflating: train/TRAIN_72347.png
#   inflating: train/TRAIN_72348.png
#   inflating: train/TRAIN_72349.png
#   inflating: train/TRAIN_72350.png
#   inflating: train/TRAIN_72351.png
#   inflating: train/TRAIN_72352.png
#   inflating: train/TRAIN_72353.png
#   inflating: train/TRAIN_72354.png
#   inflating: train/TRAIN_72355.png
#   inflating: train/TRAIN_72356.png
#   inflating: train/TRAIN_72357.png
#   inflating: train/TRAIN_72358.png
#   inflating: train/TRAIN_72359.png
#   inflating: train/TRAIN_72360.png
#   inflating: train/TRAIN_72361.png
#   inflating: train/TRAIN_72362.png
#   inflating: train/TRAIN_72363.png
#   inflating: train/TRAIN_72364.png
#   inflating: train/TRAIN_72365.png
#   inflating: train/TRAIN_72366.png
#   inflating: train/TRAIN_72367.png
#   inflating: train/TRAIN_72368.png
#   inflating: train/TRAIN_72369.png
#   inflating: train/TRAIN_72370.png
#   inflating: train/TRAIN_72371.png
#   inflating: train/TRAIN_72372.png
#   inflating: train/TRAIN_72373.png
#   inflating: train/TRAIN_72374.png
#   inflating: train/TRAIN_72375.png
#   inflating: train/TRAIN_72376.png
#   inflating: train/TRAIN_72377.png
#   inflating: train/TRAIN_72378.png
#   inflating: train/TRAIN_72379.png
#   inflating: train/TRAIN_72380.png
#   inflating: train/TRAIN_72381.png
#   inflating: train/TRAIN_72382.png
#   inflating: train/TRAIN_72383.png
#   inflating: train/TRAIN_72384.png
#   inflating: train/TRAIN_72385.png
#   inflating: train/TRAIN_72386.png
#   inflating: train/TRAIN_72387.png
#   inflating: train/TRAIN_72388.png
#   inflating: train/TRAIN_72389.png
#   inflating: train/TRAIN_72390.png
#   inflating: train/TRAIN_72391.png
#   inflating: train/TRAIN_72392.png
#   inflating: train/TRAIN_72393.png
#   inflating: train/TRAIN_72394.png
#   inflating: train/TRAIN_72395.png
#   inflating: train/TRAIN_72396.png
#   inflating: train/TRAIN_72397.png
#   inflating: train/TRAIN_72398.png
#   inflating: train/TRAIN_72399.png
#   inflating: train/TRAIN_72400.png
#   inflating: train/TRAIN_72401.png
#   inflating: train/TRAIN_72402.png
#   inflating: train/TRAIN_72403.png
#   inflating: train/TRAIN_72404.png
#   inflating: train/TRAIN_72405.png
#   inflating: train/TRAIN_72406.png
#   inflating: train/TRAIN_72407.png
#   inflating: train/TRAIN_72408.png
#   inflating: train/TRAIN_72409.png
#   inflating: train/TRAIN_72410.png
#   inflating: train/TRAIN_72411.png
#   inflating: train/TRAIN_72412.png
#   inflating: train/TRAIN_72413.png
#   inflating: train/TRAIN_72414.png
#   inflating: train/TRAIN_72415.png
#   inflating: train/TRAIN_72416.png
#   inflating: train/TRAIN_72417.png
#   inflating: train/TRAIN_72418.png
#   inflating: train/TRAIN_72419.png
#   inflating: train/TRAIN_72420.png
#   inflating: train/TRAIN_72421.png
#   inflating: train/TRAIN_72422.png
#   inflating: train/TRAIN_72423.png
#   inflating: train/TRAIN_72424.png
#   inflating: train/TRAIN_72425.png
#   inflating: train/TRAIN_72426.png
#   inflating: train/TRAIN_72427.png
#   inflating: train/TRAIN_72428.png
#   inflating: train/TRAIN_72429.png
#   inflating: train/TRAIN_72430.png
#   inflating: train/TRAIN_72431.png
#   inflating: train/TRAIN_72432.png
#   inflating: train/TRAIN_72433.png
#   inflating: train/TRAIN_72434.png
#   inflating: train/TRAIN_72435.png
#   inflating: train/TRAIN_72436.png
#   inflating: train/TRAIN_72437.png
#   inflating: train/TRAIN_72438.png
#   inflating: train/TRAIN_72439.png
#   inflating: train/TRAIN_72440.png
#   inflating: train/TRAIN_72441.png
#   inflating: train/TRAIN_72442.png
#   inflating: train/TRAIN_72443.png
#   inflating: train/TRAIN_72444.png
#   inflating: train/TRAIN_72445.png
#   inflating: train/TRAIN_72446.png
#   inflating: train/TRAIN_72447.png
#   inflating: train/TRAIN_72448.png
#   inflating: train/TRAIN_72449.png
#   inflating: train/TRAIN_72450.png
#   inflating: train/TRAIN_72451.png
#   inflating: train/TRAIN_72452.png
#   inflating: train/TRAIN_72453.png
#   inflating: train/TRAIN_72454.png
#   inflating: train/TRAIN_72455.png
#   inflating: train/TRAIN_72456.png
#   inflating: train/TRAIN_72457.png
#   inflating: train/TRAIN_72458.png
#   inflating: train/TRAIN_72459.png
#   inflating: train/TRAIN_72460.png
#   inflating: train/TRAIN_72461.png
#   inflating: train/TRAIN_72462.png
#   inflating: train/TRAIN_72463.png
#   inflating: train/TRAIN_72464.png
#   inflating: train/TRAIN_72465.png
#   inflating: train/TRAIN_72466.png
#   inflating: train/TRAIN_72467.png
#   inflating: train/TRAIN_72468.png
#   inflating: train/TRAIN_72469.png
#   inflating: train/TRAIN_72470.png
#   inflating: train/TRAIN_72471.png
#   inflating: train/TRAIN_72472.png
#   inflating: train/TRAIN_72473.png
#   inflating: train/TRAIN_72474.png
#   inflating: train/TRAIN_72475.png
#   inflating: train/TRAIN_72476.png
#   inflating: train/TRAIN_72477.png
#   inflating: train/TRAIN_72478.png
#   inflating: train/TRAIN_72479.png
#   inflating: train/TRAIN_72480.png
#   inflating: train/TRAIN_72481.png
#   inflating: train/TRAIN_72482.png
#   inflating: train/TRAIN_72483.png
#   inflating: train/TRAIN_72484.png
#   inflating: train/TRAIN_72485.png
#   inflating: train/TRAIN_72486.png
#   inflating: train/TRAIN_72487.png
#   inflating: train/TRAIN_72488.png
#   inflating: train/TRAIN_72489.png
#   inflating: train/TRAIN_72490.png
#   inflating: train/TRAIN_72491.png
#   inflating: train/TRAIN_72492.png
#   inflating: train/TRAIN_72493.png
#   inflating: train/TRAIN_72494.png
#   inflating: train/TRAIN_72495.png
#   inflating: train/TRAIN_72496.png
#   inflating: train/TRAIN_72497.png
#   inflating: train/TRAIN_72498.png
#   inflating: train/TRAIN_72499.png
#   inflating: train/TRAIN_72500.png
#   inflating: train/TRAIN_72501.png
#   inflating: train/TRAIN_72502.png
#   inflating: train/TRAIN_72503.png
#   inflating: train/TRAIN_72504.png
#   inflating: train/TRAIN_72505.png
#   inflating: train/TRAIN_72506.png
#   inflating: train/TRAIN_72507.png
#   inflating: train/TRAIN_72508.png
#   inflating: train/TRAIN_72509.png
#   inflating: train/TRAIN_72510.png
#   inflating: train/TRAIN_72511.png
#   inflating: train/TRAIN_72512.png
#   inflating: train/TRAIN_72513.png
#   inflating: train/TRAIN_72514.png
#   inflating: train/TRAIN_72515.png
#   inflating: train/TRAIN_72516.png
#   inflating: train/TRAIN_72517.png
#   inflating: train/TRAIN_72518.png
#   inflating: train/TRAIN_72519.png
#   inflating: train/TRAIN_72520.png
#   inflating: train/TRAIN_72521.png
#   inflating: train/TRAIN_72522.png
#   inflating: train/TRAIN_72523.png
#   inflating: train/TRAIN_72524.png
#   inflating: train/TRAIN_72525.png
#   inflating: train/TRAIN_72526.png
#   inflating: train/TRAIN_72527.png
#   inflating: train/TRAIN_72528.png
#   inflating: train/TRAIN_72529.png
#   inflating: train/TRAIN_72530.png
#   inflating: train/TRAIN_72531.png
#   inflating: train/TRAIN_72532.png
#   inflating: train/TRAIN_72533.png
#   inflating: train/TRAIN_72534.png
#   inflating: train/TRAIN_72535.png
#   inflating: train/TRAIN_72536.png
#   inflating: train/TRAIN_72537.png
#   inflating: train/TRAIN_72538.png
#   inflating: train/TRAIN_72539.png
#   inflating: train/TRAIN_72540.png
#   inflating: train/TRAIN_72541.png
#   inflating: train/TRAIN_72542.png
#   inflating: train/TRAIN_72543.png
#   inflating: train/TRAIN_72544.png
#   inflating: train/TRAIN_72545.png
#   inflating: train/TRAIN_72546.png
#   inflating: train/TRAIN_72547.png
#   inflating: train/TRAIN_72548.png
#   inflating: train/TRAIN_72549.png
#   inflating: train/TRAIN_72550.png
#   inflating: train/TRAIN_72551.png
#   inflating: train/TRAIN_72552.png
#   inflating: train/TRAIN_72553.png
#   inflating: train/TRAIN_72554.png
#   inflating: train/TRAIN_72555.png
#   inflating: train/TRAIN_72556.png
#   inflating: train/TRAIN_72557.png
#   inflating: train/TRAIN_72558.png
#   inflating: train/TRAIN_72559.png
#   inflating: train/TRAIN_72560.png
#   inflating: train/TRAIN_72561.png
#   inflating: train/TRAIN_72562.png
#   inflating: train/TRAIN_72563.png
#   inflating: train/TRAIN_72564.png
#   inflating: train/TRAIN_72565.png
#   inflating: train/TRAIN_72566.png
#   inflating: train/TRAIN_72567.png
#   inflating: train/TRAIN_72568.png
#   inflating: train/TRAIN_72569.png
#   inflating: train/TRAIN_72570.png
#   inflating: train/TRAIN_72571.png
#   inflating: train/TRAIN_72572.png
#   inflating: train/TRAIN_72573.png
#   inflating: train/TRAIN_72574.png
#   inflating: train/TRAIN_72575.png
#   inflating: train/TRAIN_72576.png
#   inflating: train/TRAIN_72577.png
#   inflating: train/TRAIN_72578.png
#   inflating: train/TRAIN_72579.png
#   inflating: train/TRAIN_72580.png
#   inflating: train/TRAIN_72581.png
#   inflating: train/TRAIN_72582.png
#   inflating: train/TRAIN_72583.png
#   inflating: train/TRAIN_72584.png
#   inflating: train/TRAIN_72585.png
#   inflating: train/TRAIN_72586.png
#   inflating: train/TRAIN_72587.png
#   inflating: train/TRAIN_72588.png
#   inflating: train/TRAIN_72589.png
#   inflating: train/TRAIN_72590.png
#   inflating: train/TRAIN_72591.png
#   inflating: train/TRAIN_72592.png
#   inflating: train/TRAIN_72593.png
#   inflating: train/TRAIN_72594.png
#   inflating: train/TRAIN_72595.png
#   inflating: train/TRAIN_72596.png
#   inflating: train/TRAIN_72597.png
#   inflating: train/TRAIN_72598.png
#   inflating: train/TRAIN_72599.png
#   inflating: train/TRAIN_72600.png
#   inflating: train/TRAIN_72601.png
#   inflating: train/TRAIN_72602.png
#   inflating: train/TRAIN_72603.png
#   inflating: train/TRAIN_72604.png
#   inflating: train/TRAIN_72605.png
#   inflating: train/TRAIN_72606.png
#   inflating: train/TRAIN_72607.png
#   inflating: train/TRAIN_72608.png
#   inflating: train/TRAIN_72609.png
#   inflating: train/TRAIN_72610.png
#   inflating: train/TRAIN_72611.png
#   inflating: train/TRAIN_72612.png
#   inflating: train/TRAIN_72613.png
#   inflating: train/TRAIN_72614.png
#   inflating: train/TRAIN_72615.png
#   inflating: train/TRAIN_72616.png
#   inflating: train/TRAIN_72617.png
#   inflating: train/TRAIN_72618.png
#   inflating: train/TRAIN_72619.png
#   inflating: train/TRAIN_72620.png
#   inflating: train/TRAIN_72621.png
#   inflating: train/TRAIN_72622.png
#   inflating: train/TRAIN_72623.png
#   inflating: train/TRAIN_72624.png
#   inflating: train/TRAIN_72625.png
#   inflating: train/TRAIN_72626.png
#   inflating: train/TRAIN_72627.png
#   inflating: train/TRAIN_72628.png
#   inflating: train/TRAIN_72629.png
#   inflating: train/TRAIN_72630.png
#   inflating: train/TRAIN_72631.png
#   inflating: train/TRAIN_72632.png
#   inflating: train/TRAIN_72633.png
#   inflating: train/TRAIN_72634.png
#   inflating: train/TRAIN_72635.png
#   inflating: train/TRAIN_72636.png
#   inflating: train/TRAIN_72637.png
#   inflating: train/TRAIN_72638.png
#   inflating: train/TRAIN_72639.png
#   inflating: train/TRAIN_72640.png
#   inflating: train/TRAIN_72641.png
#   inflating: train/TRAIN_72642.png
#   inflating: train/TRAIN_72643.png
#   inflating: train/TRAIN_72644.png
#   inflating: train/TRAIN_72645.png
#   inflating: train/TRAIN_72646.png
#   inflating: train/TRAIN_72647.png
#   inflating: train/TRAIN_72648.png
#   inflating: train/TRAIN_72649.png
#   inflating: train/TRAIN_72650.png
#   inflating: train/TRAIN_72651.png
#   inflating: train/TRAIN_72652.png
#   inflating: train/TRAIN_72653.png
#   inflating: train/TRAIN_72654.png
#   inflating: train/TRAIN_72655.png
#   inflating: train/TRAIN_72656.png
#   inflating: train/TRAIN_72657.png
#   inflating: train/TRAIN_72658.png
#   inflating: train/TRAIN_72659.png
#   inflating: train/TRAIN_72660.png
#   inflating: train/TRAIN_72661.png
#   inflating: train/TRAIN_72662.png
#   inflating: train/TRAIN_72663.png
#   inflating: train/TRAIN_72664.png
#   inflating: train/TRAIN_72665.png
#   inflating: train/TRAIN_72666.png
#   inflating: train/TRAIN_72667.png
#   inflating: train/TRAIN_72668.png
#   inflating: train/TRAIN_72669.png
#   inflating: train/TRAIN_72670.png
#   inflating: train/TRAIN_72671.png
#   inflating: train/TRAIN_72672.png
#   inflating: train/TRAIN_72673.png
#   inflating: train/TRAIN_72674.png
#   inflating: train/TRAIN_72675.png
#   inflating: train/TRAIN_72676.png
#   inflating: train/TRAIN_72677.png
#   inflating: train/TRAIN_72678.png
#   inflating: train/TRAIN_72679.png
#   inflating: train/TRAIN_72680.png
#   inflating: train/TRAIN_72681.png
#   inflating: train/TRAIN_72682.png
#   inflating: train/TRAIN_72683.png
#   inflating: train/TRAIN_72684.png
#   inflating: train/TRAIN_72685.png
#   inflating: train/TRAIN_72686.png
#   inflating: train/TRAIN_72687.png
#   inflating: train/TRAIN_72688.png
#   inflating: train/TRAIN_72689.png
#   inflating: train/TRAIN_72690.png
#   inflating: train/TRAIN_72691.png
#   inflating: train/TRAIN_72692.png
#   inflating: train/TRAIN_72693.png
#   inflating: train/TRAIN_72694.png
#   inflating: train/TRAIN_72695.png
#   inflating: train/TRAIN_72696.png
#   inflating: train/TRAIN_72697.png
#   inflating: train/TRAIN_72698.png
#   inflating: train/TRAIN_72699.png
#   inflating: train/TRAIN_72700.png
#   inflating: train/TRAIN_72701.png
#   inflating: train/TRAIN_72702.png
#   inflating: train/TRAIN_72703.png
#   inflating: train/TRAIN_72704.png
#   inflating: train/TRAIN_72705.png
#   inflating: train/TRAIN_72706.png
#   inflating: train/TRAIN_72707.png
#   inflating: train/TRAIN_72708.png
#   inflating: train/TRAIN_72709.png
#   inflating: train/TRAIN_72710.png
#   inflating: train/TRAIN_72711.png
#   inflating: train/TRAIN_72712.png
#   inflating: train/TRAIN_72713.png
#   inflating: train/TRAIN_72714.png
#   inflating: train/TRAIN_72715.png
#   inflating: train/TRAIN_72716.png
#   inflating: train/TRAIN_72717.png
#   inflating: train/TRAIN_72718.png
#   inflating: train/TRAIN_72719.png
#   inflating: train/TRAIN_72720.png
#   inflating: train/TRAIN_72721.png
#   inflating: train/TRAIN_72722.png
#   inflating: train/TRAIN_72723.png
#   inflating: train/TRAIN_72724.png
#   inflating: train/TRAIN_72725.png
#   inflating: train/TRAIN_72726.png
#   inflating: train/TRAIN_72727.png
#   inflating: train/TRAIN_72728.png
#   inflating: train/TRAIN_72729.png
#   inflating: train/TRAIN_72730.png
#   inflating: train/TRAIN_72731.png
#   inflating: train/TRAIN_72732.png
#   inflating: train/TRAIN_72733.png
#   inflating: train/TRAIN_72734.png
#   inflating: train/TRAIN_72735.png
#   inflating: train/TRAIN_72736.png
#   inflating: train/TRAIN_72737.png
#   inflating: train/TRAIN_72738.png
#   inflating: train/TRAIN_72739.png
#   inflating: train/TRAIN_72740.png
#   inflating: train/TRAIN_72741.png
#   inflating: train/TRAIN_72742.png
#   inflating: train/TRAIN_72743.png
#   inflating: train/TRAIN_72744.png
#   inflating: train/TRAIN_72745.png
#   inflating: train/TRAIN_72746.png
#   inflating: train/TRAIN_72747.png
#   inflating: train/TRAIN_72748.png
#   inflating: train/TRAIN_72749.png
#   inflating: train/TRAIN_72750.png
#   inflating: train/TRAIN_72751.png
#   inflating: train/TRAIN_72752.png
#   inflating: train/TRAIN_72753.png
#   inflating: train/TRAIN_72754.png
#   inflating: train/TRAIN_72755.png
#   inflating: train/TRAIN_72756.png
#   inflating: train/TRAIN_72757.png
#   inflating: train/TRAIN_72758.png
#   inflating: train/TRAIN_72759.png
#   inflating: train/TRAIN_72760.png
#   inflating: train/TRAIN_72761.png
#   inflating: train/TRAIN_72762.png
#   inflating: train/TRAIN_72763.png
#   inflating: train/TRAIN_72764.png
#   inflating: train/TRAIN_72765.png
#   inflating: train/TRAIN_72766.png
#   inflating: train/TRAIN_72767.png
#   inflating: train/TRAIN_72768.png
#   inflating: train/TRAIN_72769.png
#   inflating: train/TRAIN_72770.png
#   inflating: train/TRAIN_72771.png
#   inflating: train/TRAIN_72772.png
#   inflating: train/TRAIN_72773.png
#   inflating: train/TRAIN_72774.png
#   inflating: train/TRAIN_72775.png
#   inflating: train/TRAIN_72776.png
#   inflating: train/TRAIN_72777.png
#   inflating: train/TRAIN_72778.png
#   inflating: train/TRAIN_72779.png
#   inflating: train/TRAIN_72780.png
#   inflating: train/TRAIN_72781.png
#   inflating: train/TRAIN_72782.png
#   inflating: train/TRAIN_72783.png
#   inflating: train/TRAIN_72784.png
#   inflating: train/TRAIN_72785.png
#   inflating: train/TRAIN_72786.png
#   inflating: train/TRAIN_72787.png
#   inflating: train/TRAIN_72788.png
#   inflating: train/TRAIN_72789.png
#   inflating: train/TRAIN_72790.png
#   inflating: train/TRAIN_72791.png
#   inflating: train/TRAIN_72792.png
#   inflating: train/TRAIN_72793.png
#   inflating: train/TRAIN_72794.png
#   inflating: train/TRAIN_72795.png
#   inflating: train/TRAIN_72796.png
#   inflating: train/TRAIN_72797.png
#   inflating: train/TRAIN_72798.png
#   inflating: train/TRAIN_72799.png
#   inflating: train/TRAIN_72800.png
#   inflating: train/TRAIN_72801.png
#   inflating: train/TRAIN_72802.png
#   inflating: train/TRAIN_72803.png
#   inflating: train/TRAIN_72804.png
#   inflating: train/TRAIN_72805.png
#   inflating: train/TRAIN_72806.png
#   inflating: train/TRAIN_72807.png
#   inflating: train/TRAIN_72808.png
#   inflating: train/TRAIN_72809.png
#   inflating: train/TRAIN_72810.png
#   inflating: train/TRAIN_72811.png
#   inflating: train/TRAIN_72812.png
#   inflating: train/TRAIN_72813.png
#   inflating: train/TRAIN_72814.png
#   inflating: train/TRAIN_72815.png
#   inflating: train/TRAIN_72816.png
#   inflating: train/TRAIN_72817.png
#   inflating: train/TRAIN_72818.png
#   inflating: train/TRAIN_72819.png
#   inflating: train/TRAIN_72820.png
#   inflating: train/TRAIN_72821.png
#   inflating: train/TRAIN_72822.png
#   inflating: train/TRAIN_72823.png
#   inflating: train/TRAIN_72824.png
#   inflating: train/TRAIN_72825.png
#   inflating: train/TRAIN_72826.png
#   inflating: train/TRAIN_72827.png
#   inflating: train/TRAIN_72828.png
#   inflating: train/TRAIN_72829.png
#   inflating: train/TRAIN_72830.png
#   inflating: train/TRAIN_72831.png
#   inflating: train/TRAIN_72832.png
#   inflating: train/TRAIN_72833.png
#   inflating: train/TRAIN_72834.png
#   inflating: train/TRAIN_72835.png
#   inflating: train/TRAIN_72836.png
#   inflating: train/TRAIN_72837.png
#   inflating: train/TRAIN_72838.png
#   inflating: train/TRAIN_72839.png
#   inflating: train/TRAIN_72840.png
#   inflating: train/TRAIN_72841.png
#   inflating: train/TRAIN_72842.png
#   inflating: train/TRAIN_72843.png
#   inflating: train/TRAIN_72844.png
#   inflating: train/TRAIN_72845.png
#   inflating: train/TRAIN_72846.png
#   inflating: train/TRAIN_72847.png
#   inflating: train/TRAIN_72848.png
#   inflating: train/TRAIN_72849.png
#   inflating: train/TRAIN_72850.png
#   inflating: train/TRAIN_72851.png
#   inflating: train/TRAIN_72852.png
#   inflating: train/TRAIN_72853.png
#   inflating: train/TRAIN_72854.png
#   inflating: train/TRAIN_72855.png
#   inflating: train/TRAIN_72856.png
#   inflating: train/TRAIN_72857.png
#   inflating: train/TRAIN_72858.png
#   inflating: train/TRAIN_72859.png
#   inflating: train/TRAIN_72860.png
#   inflating: train/TRAIN_72861.png
#   inflating: train/TRAIN_72862.png
#   inflating: train/TRAIN_72863.png
#   inflating: train/TRAIN_72864.png
#   inflating: train/TRAIN_72865.png
#   inflating: train/TRAIN_72866.png
#   inflating: train/TRAIN_72867.png
#   inflating: train/TRAIN_72868.png
#   inflating: train/TRAIN_72869.png
#   inflating: train/TRAIN_72870.png
#   inflating: train/TRAIN_72871.png
#   inflating: train/TRAIN_72872.png
#   inflating: train/TRAIN_72873.png
#   inflating: train/TRAIN_72874.png
#   inflating: train/TRAIN_72875.png
#   inflating: train/TRAIN_72876.png
#   inflating: train/TRAIN_72877.png
#   inflating: train/TRAIN_72878.png
#   inflating: train/TRAIN_72879.png
#   inflating: train/TRAIN_72880.png
#   inflating: train/TRAIN_72881.png
#   inflating: train/TRAIN_72882.png
#   inflating: train/TRAIN_72883.png
#   inflating: train/TRAIN_72884.png
#   inflating: train/TRAIN_72885.png
#   inflating: train/TRAIN_72886.png
#   inflating: train/TRAIN_72887.png
#   inflating: train/TRAIN_72888.png
#   inflating: train/TRAIN_72889.png
#   inflating: train/TRAIN_72890.png
#   inflating: train/TRAIN_72891.png
#   inflating: train/TRAIN_72892.png
#   inflating: train/TRAIN_72893.png
#   inflating: train/TRAIN_72894.png
#   inflating: train/TRAIN_72895.png
#   inflating: train/TRAIN_72896.png
#   inflating: train/TRAIN_72897.png
#   inflating: train/TRAIN_72898.png
#   inflating: train/TRAIN_72899.png
#   inflating: train/TRAIN_72900.png
#   inflating: train/TRAIN_72901.png
#   inflating: train/TRAIN_72902.png
#   inflating: train/TRAIN_72903.png
#   inflating: train/TRAIN_72904.png
#   inflating: train/TRAIN_72905.png
#   inflating: train/TRAIN_72906.png
#   inflating: train/TRAIN_72907.png
#   inflating: train/TRAIN_72908.png
#   inflating: train/TRAIN_72909.png
#   inflating: train/TRAIN_72910.png
#   inflating: train/TRAIN_72911.png
#   inflating: train/TRAIN_72912.png
#   inflating: train/TRAIN_72913.png
#   inflating: train/TRAIN_72914.png
#   inflating: train/TRAIN_72915.png
#   inflating: train/TRAIN_72916.png
#   inflating: train/TRAIN_72917.png
#   inflating: train/TRAIN_72918.png
#   inflating: train/TRAIN_72919.png
#   inflating: train/TRAIN_72920.png
#   inflating: train/TRAIN_72921.png
#   inflating: train/TRAIN_72922.png
#   inflating: train/TRAIN_72923.png
#   inflating: train/TRAIN_72924.png
#   inflating: train/TRAIN_72925.png
#   inflating: train/TRAIN_72926.png
#   inflating: train/TRAIN_72927.png
#   inflating: train/TRAIN_72928.png
#   inflating: train/TRAIN_72929.png
#   inflating: train/TRAIN_72930.png
#   inflating: train/TRAIN_72931.png
#   inflating: train/TRAIN_72932.png
#   inflating: train/TRAIN_72933.png
#   inflating: train/TRAIN_72934.png
#   inflating: train/TRAIN_72935.png
#   inflating: train/TRAIN_72936.png
#   inflating: train/TRAIN_72937.png
#   inflating: train/TRAIN_72938.png
#   inflating: train/TRAIN_72939.png
#   inflating: train/TRAIN_72940.png
#   inflating: train/TRAIN_72941.png
#   inflating: train/TRAIN_72942.png
#   inflating: train/TRAIN_72943.png
#   inflating: train/TRAIN_72944.png
#   inflating: train/TRAIN_72945.png
#   inflating: train/TRAIN_72946.png
#   inflating: train/TRAIN_72947.png
#   inflating: train/TRAIN_72948.png
#   inflating: train/TRAIN_72949.png
#   inflating: train/TRAIN_72950.png
#   inflating: train/TRAIN_72951.png
#   inflating: train/TRAIN_72952.png
#   inflating: train/TRAIN_72953.png
#   inflating: train/TRAIN_72954.png
#   inflating: train/TRAIN_72955.png
#   inflating: train/TRAIN_72956.png
#   inflating: train/TRAIN_72957.png
#   inflating: train/TRAIN_72958.png
#   inflating: train/TRAIN_72959.png
#   inflating: train/TRAIN_72960.png
#   inflating: train/TRAIN_72961.png
#   inflating: train/TRAIN_72962.png
#   inflating: train/TRAIN_72963.png
#   inflating: train/TRAIN_72964.png
#   inflating: train/TRAIN_72965.png
#   inflating: train/TRAIN_72966.png
#   inflating: train/TRAIN_72967.png
#   inflating: train/TRAIN_72968.png
#   inflating: train/TRAIN_72969.png
#   inflating: train/TRAIN_72970.png
#   inflating: train/TRAIN_72971.png
#   inflating: train/TRAIN_72972.png
#   inflating: train/TRAIN_72973.png
#   inflating: train/TRAIN_72974.png
#   inflating: train/TRAIN_72975.png
#   inflating: train/TRAIN_72976.png
#   inflating: train/TRAIN_72977.png
#   inflating: train/TRAIN_72978.png
#   inflating: train/TRAIN_72979.png
#   inflating: train/TRAIN_72980.png
#   inflating: train/TRAIN_72981.png
#   inflating: train/TRAIN_72982.png
#   inflating: train/TRAIN_72983.png
#   inflating: train/TRAIN_72984.png
#   inflating: train/TRAIN_72985.png
#   inflating: train/TRAIN_72986.png
#   inflating: train/TRAIN_72987.png
#   inflating: train/TRAIN_72988.png
#   inflating: train/TRAIN_72989.png
#   inflating: train/TRAIN_72990.png
#   inflating: train/TRAIN_72991.png
#   inflating: train/TRAIN_72992.png
#   inflating: train/TRAIN_72993.png
#   inflating: train/TRAIN_72994.png
#   inflating: train/TRAIN_72995.png
#   inflating: train/TRAIN_72996.png
#   inflating: train/TRAIN_72997.png
#   inflating: train/TRAIN_72998.png
#   inflating: train/TRAIN_72999.png
#   inflating: train/TRAIN_73000.png
#   inflating: train/TRAIN_73001.png
#   inflating: train/TRAIN_73002.png
#   inflating: train/TRAIN_73003.png
#   inflating: train/TRAIN_73004.png
#   inflating: train/TRAIN_73005.png
#   inflating: train/TRAIN_73006.png
#   inflating: train/TRAIN_73007.png
#   inflating: train/TRAIN_73008.png
#   inflating: train/TRAIN_73009.png
#   inflating: train/TRAIN_73010.png
#   inflating: train/TRAIN_73011.png
#   inflating: train/TRAIN_73012.png
#   inflating: train/TRAIN_73013.png
#   inflating: train/TRAIN_73014.png
#   inflating: train/TRAIN_73015.png
#   inflating: train/TRAIN_73016.png
#   inflating: train/TRAIN_73017.png
#   inflating: train/TRAIN_73018.png
#   inflating: train/TRAIN_73019.png
#   inflating: train/TRAIN_73020.png
#   inflating: train/TRAIN_73021.png
#   inflating: train/TRAIN_73022.png
#   inflating: train/TRAIN_73023.png
#   inflating: train/TRAIN_73024.png
#   inflating: train/TRAIN_73025.png
#   inflating: train/TRAIN_73026.png
#   inflating: train/TRAIN_73027.png
#   inflating: train/TRAIN_73028.png
#   inflating: train/TRAIN_73029.png
#   inflating: train/TRAIN_73030.png
#   inflating: train/TRAIN_73031.png
#   inflating: train/TRAIN_73032.png
#   inflating: train/TRAIN_73033.png
#   inflating: train/TRAIN_73034.png
#   inflating: train/TRAIN_73035.png
#   inflating: train/TRAIN_73036.png
#   inflating: train/TRAIN_73037.png
#   inflating: train/TRAIN_73038.png
#   inflating: train/TRAIN_73039.png
#   inflating: train/TRAIN_73040.png
#   inflating: train/TRAIN_73041.png
#   inflating: train/TRAIN_73042.png
#   inflating: train/TRAIN_73043.png
#   inflating: train/TRAIN_73044.png
#   inflating: train/TRAIN_73045.png
#   inflating: train/TRAIN_73046.png
#   inflating: train/TRAIN_73047.png
#   inflating: train/TRAIN_73048.png
#   inflating: train/TRAIN_73049.png
#   inflating: train/TRAIN_73050.png
#   inflating: train/TRAIN_73051.png
#   inflating: train/TRAIN_73052.png
#   inflating: train/TRAIN_73053.png
#   inflating: train/TRAIN_73054.png
#   inflating: train/TRAIN_73055.png
#   inflating: train/TRAIN_73056.png
#   inflating: train/TRAIN_73057.png
#   inflating: train/TRAIN_73058.png
#   inflating: train/TRAIN_73059.png
#   inflating: train/TRAIN_73060.png
#   inflating: train/TRAIN_73061.png
#   inflating: train/TRAIN_73062.png
#   inflating: train/TRAIN_73063.png
#   inflating: train/TRAIN_73064.png
#   inflating: train/TRAIN_73065.png
#   inflating: train/TRAIN_73066.png
#   inflating: train/TRAIN_73067.png
#   inflating: train/TRAIN_73068.png
#   inflating: train/TRAIN_73069.png
#   inflating: train/TRAIN_73070.png
#   inflating: train/TRAIN_73071.png
#   inflating: train/TRAIN_73072.png
#   inflating: train/TRAIN_73073.png
#   inflating: train/TRAIN_73074.png
#   inflating: train/TRAIN_73075.png
#   inflating: train/TRAIN_73076.png
#   inflating: train/TRAIN_73077.png
#   inflating: train/TRAIN_73078.png
#   inflating: train/TRAIN_73079.png
#   inflating: train/TRAIN_73080.png
#   inflating: train/TRAIN_73081.png
#   inflating: train/TRAIN_73082.png
#   inflating: train/TRAIN_73083.png
#   inflating: train/TRAIN_73084.png
#   inflating: train/TRAIN_73085.png
#   inflating: train/TRAIN_73086.png
#   inflating: train/TRAIN_73087.png
#   inflating: train/TRAIN_73088.png
#   inflating: train/TRAIN_73089.png
#   inflating: train/TRAIN_73090.png
#   inflating: train/TRAIN_73091.png
#   inflating: train/TRAIN_73092.png
#   inflating: train/TRAIN_73093.png
#   inflating: train/TRAIN_73094.png
#   inflating: train/TRAIN_73095.png
#   inflating: train/TRAIN_73096.png
#   inflating: train/TRAIN_73097.png
#   inflating: train/TRAIN_73098.png
#   inflating: train/TRAIN_73099.png
#   inflating: train/TRAIN_73100.png
#   inflating: train/TRAIN_73101.png
#   inflating: train/TRAIN_73102.png
#   inflating: train/TRAIN_73103.png
#   inflating: train/TRAIN_73104.png
#   inflating: train/TRAIN_73105.png
#   inflating: train/TRAIN_73106.png
#   inflating: train/TRAIN_73107.png
#   inflating: train/TRAIN_73108.png
#   inflating: train/TRAIN_73109.png
#   inflating: train/TRAIN_73110.png
#   inflating: train/TRAIN_73111.png
#   inflating: train/TRAIN_73112.png
#   inflating: train/TRAIN_73113.png
#   inflating: train/TRAIN_73114.png
#   inflating: train/TRAIN_73115.png
#   inflating: train/TRAIN_73116.png
#   inflating: train/TRAIN_73117.png
#   inflating: train/TRAIN_73118.png
#   inflating: train/TRAIN_73119.png
#   inflating: train/TRAIN_73120.png
#   inflating: train/TRAIN_73121.png
#   inflating: train/TRAIN_73122.png
#   inflating: train/TRAIN_73123.png
#   inflating: train/TRAIN_73124.png
#   inflating: train/TRAIN_73125.png
#   inflating: train/TRAIN_73126.png
#   inflating: train/TRAIN_73127.png
#   inflating: train/TRAIN_73128.png
#   inflating: train/TRAIN_73129.png
#   inflating: train/TRAIN_73130.png
#   inflating: train/TRAIN_73131.png
#   inflating: train/TRAIN_73132.png
#   inflating: train/TRAIN_73133.png
#   inflating: train/TRAIN_73134.png
#   inflating: train/TRAIN_73135.png
#   inflating: train/TRAIN_73136.png
#   inflating: train/TRAIN_73137.png
#   inflating: train/TRAIN_73138.png
#   inflating: train/TRAIN_73139.png
#   inflating: train/TRAIN_73140.png
#   inflating: train/TRAIN_73141.png
#   inflating: train/TRAIN_73142.png
#   inflating: train/TRAIN_73143.png
#   inflating: train/TRAIN_73144.png
#   inflating: train/TRAIN_73145.png
#   inflating: train/TRAIN_73146.png
#   inflating: train/TRAIN_73147.png
#   inflating: train/TRAIN_73148.png
#   inflating: train/TRAIN_73149.png
# ...
#   inflating: train/TRAIN_76467.png
#   inflating: train/TRAIN_76468.png
#   inflating: train/TRAIN_76469.png
#   inflating: train/TRAIN_76470.png
#   inflating: train/TRAIN_76471.png
#   inflating: train/TRAIN_76472.png
#   inflating: train/TRAIN_76473.png
#   inflating: train/TRAIN_76474.png
#   inflating: train/TRAIN_76475.png
#   inflating: train/TRAIN_76476.png
#   inflating: train/TRAIN_76477.png
#   inflating: train/TRAIN_76478.png
#   inflating: train/TRAIN_76479.png
#   inflating: train/TRAIN_76480.png
#   inflating: train/TRAIN_76481.png
#   inflating: train/TRAIN_76482.png
#   inflating: train/TRAIN_76483.png
#   inflating: train/TRAIN_76484.png
#   inflating: train/TRAIN_76485.png
#   inflating: train/TRAIN_76486.png
#   inflating: train/TRAIN_76487.png
#   inflating: train/TRAIN_76488.png
#   inflating: train/TRAIN_76489.png
#   inflating: train/TRAIN_76490.png
#   inflating: train/TRAIN_76491.png
#   inflating: train/TRAIN_76492.png
#   inflating: train/TRAIN_76493.png
#   inflating: train/TRAIN_76494.png
#   inflating: train/TRAIN_76495.png
#   inflating: train/TRAIN_76496.png
#   inflating: train/TRAIN_76497.png
#   inflating: train/TRAIN_76498.png
#   inflating: train/TRAIN_76499.png
#   inflating: train/TRAIN_76500.png
#   inflating: train/TRAIN_76501.png
#   inflating: train/TRAIN_76502.png
#   inflating: train/TRAIN_76503.png
#   inflating: train/TRAIN_76504.png
#   inflating: train/TRAIN_76505.png
#   inflating: train/TRAIN_76506.png
#   inflating: train/TRAIN_76507.png
#   inflating: train/TRAIN_76508.png
#   inflating: train/TRAIN_76509.png
#   inflating: train/TRAIN_76510.png
#   inflating: train/TRAIN_76511.png
#   inflating: train/TRAIN_76512.png
#   inflating: train/TRAIN_76513.png
#   inflating: train/TRAIN_76514.png
#   inflating: train/TRAIN_76515.png
#   inflating: train/TRAIN_76516.png
#   inflating: train/TRAIN_76517.png
#   inflating: train/TRAIN_76518.png
#   inflating: train/TRAIN_76519.png
#   inflating: train/TRAIN_76520.png
#   inflating: train/TRAIN_76521.png
#   inflating: train/TRAIN_76522.png
#   inflating: train/TRAIN_76523.png
#   inflating: train/TRAIN_76524.png
#   inflating: train/TRAIN_76525.png
#   inflating: train/TRAIN_76526.png
#   inflating: train/TRAIN_76527.png
#   inflating: train/TRAIN_76528.png
#   inflating: train/TRAIN_76529.png
#   inflating: train/TRAIN_76530.png
#   inflating: train/TRAIN_76531.png
#   inflating: train/TRAIN_76532.png
#   inflating: train/TRAIN_76533.png
#   inflating: train/TRAIN_76534.png
#   inflating: train/TRAIN_76535.png
#   inflating: train/TRAIN_76536.png
#   inflating: train/TRAIN_76537.png
#   inflating: train/TRAIN_76538.png
#   inflating: train/TRAIN_76539.png
#   inflating: train/TRAIN_76540.png
#   inflating: train/TRAIN_76541.png
#   inflating: train/TRAIN_76542.png
#   inflating: train/TRAIN_76543.png
#   inflating: train/TRAIN_76544.png
#   inflating: train/TRAIN_76545.png
#   inflating: train/TRAIN_76546.png
#   inflating: train/TRAIN_76547.png
#   inflating: train/TRAIN_76548.png
#   inflating: train/TRAIN_76549.png
#   inflating: train/TRAIN_76550.png
#   inflating: train/TRAIN_76551.png
#   inflating: train/TRAIN_76552.png
#   inflating: train/TRAIN_76553.png
#   inflating: train/TRAIN_76554.png
#   inflating: train/TRAIN_76555.png
#   inflating: train/TRAIN_76556.png
#   inflating: train/TRAIN_76557.png
#   inflating: train/TRAIN_76558.png
#   inflating: train/TRAIN_76559.png
#   inflating: train/TRAIN_76560.png
#   inflating: train/TRAIN_76561.png
#   inflating: train/TRAIN_76562.png
#   inflating: train/TRAIN_76563.png
#   inflating: train/TRAIN_76564.png
#   inflating: train/TRAIN_76565.png
#   inflating: train/TRAIN_76566.png
#   inflating: train/TRAIN_76567.png
#   inflating: train/TRAIN_76568.png
#   inflating: train/TRAIN_76569.png
#   inflating: train/TRAIN_76570.png
#   inflating: train/TRAIN_76571.png
#   inflating: train/TRAIN_76572.png
#   inflating: train/TRAIN_76573.png
#   inflating: train/TRAIN_76574.png
#   inflating: train/TRAIN_76575.png
#   inflating: train/TRAIN_76576.png
#   inflating: train/TRAIN_76577.png
#   inflating: train/TRAIN_76578.png
#   inflating: train/TRAIN_76579.png
#   inflating: train/TRAIN_76580.png
#   inflating: train/TRAIN_76581.png
#   inflating: train/TRAIN_76582.png
#   inflating: train/TRAIN_76583.png
#   inflating: train/TRAIN_76584.png
#   inflating: train/TRAIN_76585.png
#   inflating: train/TRAIN_76586.png
#   inflating: train/TRAIN_76587.png
#   inflating: train/TRAIN_76588.png
#   inflating: train/TRAIN_76589.png
#   inflating: train/TRAIN_76590.png
#   inflating: train/TRAIN_76591.png
#   inflating: train/TRAIN_76592.png
#   inflating: train/TRAIN_76593.png
#   inflating: train/TRAIN_76594.png
#   inflating: train/TRAIN_76595.png
#   inflating: train/TRAIN_76596.png
#   inflating: train/TRAIN_76597.png
#   inflating: train/TRAIN_76598.png
#   inflating: train/TRAIN_76599.png
#   inflating: train/TRAIN_76600.png
#   inflating: train/TRAIN_76601.png
#   inflating: train/TRAIN_76602.png
#   inflating: train/TRAIN_76603.png
#   inflating: train/TRAIN_76604.png
#   inflating: train/TRAIN_76605.png
#   inflating: train/TRAIN_76606.png
#   inflating: train/TRAIN_76607.png
#   inflating: train/TRAIN_76608.png
#   inflating: train/TRAIN_76609.png
#   inflating: train/TRAIN_76610.png
#   inflating: train/TRAIN_76611.png
#   inflating: train/TRAIN_76612.png
#   inflating: train/TRAIN_76613.png
#   inflating: train/TRAIN_76614.png
#   inflating: train/TRAIN_76615.png
#   inflating: train/TRAIN_76616.png
#   inflating: train/TRAIN_76617.png
#   inflating: train/TRAIN_76618.png
#   inflating: train/TRAIN_76619.png
#   inflating: train/TRAIN_76620.png
#   inflating: train/TRAIN_76621.png
#   inflating: train/TRAIN_76622.png
#   inflating: train/TRAIN_76623.png
#   inflating: train/TRAIN_76624.png
#   inflating: train/TRAIN_76625.png
#   inflating: train/TRAIN_76626.png
#   inflating: train/TRAIN_76627.png
#   inflating: train/TRAIN_76628.png
#   inflating: train/TRAIN_76629.png
#   inflating: train/TRAIN_76630.png
#   inflating: train/TRAIN_76631.png
#   inflating: train/TRAIN_76632.png
#   inflating: train/TRAIN_76633.png
#   inflating: train/TRAIN_76634.png
#   inflating: train/TRAIN_76635.png
#   inflating: train/TRAIN_76636.png
#   inflating: train/TRAIN_76637.png
#   inflating: train/TRAIN_76638.png
#   inflating: train/TRAIN_76639.png
#   inflating: train/TRAIN_76640.png
#   inflating: train/TRAIN_76641.png
#   inflating: train/TRAIN_76642.png
#   inflating: train/TRAIN_76643.png
#   inflating: train/TRAIN_76644.png
#   inflating: train/TRAIN_76645.png
#   inflating: train/TRAIN_76646.png
#   inflating: train/TRAIN_76647.png
#   inflating: train/TRAIN_76648.png
#   inflating: train/TRAIN_76649.png
#   inflating: train/TRAIN_76650.png
#   inflating: train/TRAIN_76651.png
#   inflating: train/TRAIN_76652.png
#   inflating: train/TRAIN_76653.png
#   inflating: train/TRAIN_76654.png
#   inflating: train/TRAIN_76655.png
#   inflating: train/TRAIN_76656.png
#   inflating: train/TRAIN_76657.png
#   inflating: train/TRAIN_76658.png
#   inflating: train/TRAIN_76659.png
#   inflating: train/TRAIN_76660.png
#   inflating: train/TRAIN_76661.png
#   inflating: train/TRAIN_76662.png
#   inflating: train/TRAIN_76663.png
#   inflating: train/TRAIN_76664.png
#   inflating: train/TRAIN_76665.png
#   inflating: train/TRAIN_76666.png
#   inflating: train/TRAIN_76667.png
#   inflating: train/TRAIN_76668.png
#   inflating: train/TRAIN_76669.png
#   inflating: train/TRAIN_76670.png
#   inflating: train/TRAIN_76671.png
#   inflating: train/TRAIN_76672.png
#   inflating: train/TRAIN_76673.png
#   inflating: train/TRAIN_76674.png
#   inflating: train/TRAIN_76675.png
#   inflating: train/TRAIN_76676.png
#   inflating: train/TRAIN_76677.png
#   inflating: train/TRAIN_76678.png
#   inflating: train/TRAIN_76679.png
#   inflating: train/TRAIN_76680.png
#   inflating: train/TRAIN_76681.png
#   inflating: train/TRAIN_76682.png
#   inflating: train/TRAIN_76683.png
#   inflating: train/TRAIN_76684.png
#   inflating: train/TRAIN_76685.png
#   inflating: train/TRAIN_76686.png
#   inflating: train/TRAIN_76687.png
#   inflating: train/TRAIN_76688.png
#   inflating: train/TRAIN_76689.png
#   inflating: train/TRAIN_76690.png
#   inflating: train/TRAIN_76691.png
#   inflating: train/TRAIN_76692.png
#   inflating: train/TRAIN_76693.png
#   inflating: train/TRAIN_76694.png
#   inflating: train/TRAIN_76695.png
#   inflating: train/TRAIN_76696.png
#   inflating: train/TRAIN_76697.png
#   inflating: train/TRAIN_76698.png
#   inflating: train/TRAIN_76699.png
#   inflating: train/TRAIN_76700.png
#   inflating: train/TRAIN_76701.png
#   inflating: train/TRAIN_76702.png
#   inflating: train/TRAIN_76703.png
#   inflating: train/TRAIN_76704.png
#   inflating: train/TRAIN_76705.png
#   inflating: train/TRAIN_76706.png
#   inflating: train/TRAIN_76707.png
#   inflating: train/TRAIN_76708.png
#   inflating: train/TRAIN_76709.png
#   inflating: train/TRAIN_76710.png
#   inflating: train/TRAIN_76711.png
#   inflating: train/TRAIN_76712.png
#   inflating: train/TRAIN_76713.png
#   inflating: train/TRAIN_76714.png
#   inflating: train/TRAIN_76715.png
#   inflating: train/TRAIN_76716.png
#   inflating: train/TRAIN_76717.png
#   inflating: train/TRAIN_76718.png
#   inflating: train/TRAIN_76719.png
#   inflating: train/TRAIN_76720.png
#   inflating: train/TRAIN_76721.png
#   inflating: train/TRAIN_76722.png
#   inflating: train/TRAIN_76723.png
#   inflating: train/TRAIN_76724.png
#   inflating: train/TRAIN_76725.png
#   inflating: train/TRAIN_76726.png
#   inflating: train/TRAIN_76727.png
#   inflating: train/TRAIN_76728.png
#   inflating: train/TRAIN_76729.png
#   inflating: train/TRAIN_76730.png
#   inflating: train/TRAIN_76731.png
#   inflating: train/TRAIN_76732.png
#   inflating: train/TRAIN_76733.png
#   inflating: train/TRAIN_76734.png
#   inflating: train/TRAIN_76735.png
#   inflating: train/TRAIN_76736.png
#   inflating: train/TRAIN_76737.png
#   inflating: train/TRAIN_76738.png
#   inflating: train/TRAIN_76739.png
#   inflating: train/TRAIN_76740.png
#   inflating: train/TRAIN_76741.png
#   inflating: train/TRAIN_76742.png
#   inflating: train/TRAIN_76743.png
#   inflating: train/TRAIN_76744.png
#   inflating: train/TRAIN_76745.png
#   inflating: train/TRAIN_76746.png
#   inflating: train/TRAIN_76747.png
#   inflating: train/TRAIN_76748.png
#   inflating: train/TRAIN_76749.png
#   inflating: train/TRAIN_76750.png
#   inflating: train/TRAIN_76751.png
#   inflating: train/TRAIN_76752.png
#   inflating: train/TRAIN_76753.png
#   inflating: train/TRAIN_76754.png
#   inflating: train/TRAIN_76755.png
#   inflating: train/TRAIN_76756.png
#   inflating: train/TRAIN_76757.png
#   inflating: train/TRAIN_76758.png
#   inflating: train/TRAIN_76759.png
#   inflating: train/TRAIN_76760.png
#   inflating: train/TRAIN_76761.png
#   inflating: train/TRAIN_76762.png
#   inflating: train/TRAIN_76763.png
#   inflating: train/TRAIN_76764.png
#   inflating: train/TRAIN_76765.png
#   inflating: train/TRAIN_76766.png
#   inflating: train/TRAIN_76767.png
#   inflating: train/TRAIN_76768.png
#   inflating: train/TRAIN_76769.png
#   inflating: train/TRAIN_76770.png
#   inflating: train/TRAIN_76771.png
#   inflating: train/TRAIN_76772.png
#   inflating: train/TRAIN_76773.png
#   inflating: train/TRAIN_76774.png
#   inflating: train/TRAIN_76775.png
#   inflating: train/TRAIN_76776.png
#   inflating: train/TRAIN_76777.png
#   inflating: train/TRAIN_76778.png
#   inflating: train/TRAIN_76779.png
#   inflating: train/TRAIN_76780.png
#   inflating: train/TRAIN_76781.png
#   inflating: train/TRAIN_76782.png
#   inflating: train/TRAIN_76783.png
#   inflating: train/TRAIN_76784.png
#   inflating: train/TRAIN_76785.png
#   inflating: train/TRAIN_76786.png
#   inflating: train/TRAIN_76787.png
#   inflating: train/TRAIN_76788.png
#   inflating: train/TRAIN_76789.png
#   inflating: train/TRAIN_76790.png
#   inflating: train/TRAIN_76791.png
#   inflating: train/TRAIN_76792.png
#   inflating: train/TRAIN_76793.png
#   inflating: train/TRAIN_76794.png
#   inflating: train/TRAIN_76795.png
#   inflating: train/TRAIN_76796.png
#   inflating: train/TRAIN_76797.png
#   inflating: train/TRAIN_76798.png
#   inflating: train/TRAIN_76799.png
#   inflating: train/TRAIN_76800.png
#   inflating: train/TRAIN_76801.png
#   inflating: train/TRAIN_76802.png
#   inflating: train/TRAIN_76803.png
#   inflating: train/TRAIN_76804.png
#   inflating: train/TRAIN_76805.png
#   inflating: train/TRAIN_76806.png
#   inflating: train/TRAIN_76807.png
#   inflating: train/TRAIN_76808.png
#   inflating: train/TRAIN_76809.png
#   inflating: train/TRAIN_76810.png
#   inflating: train/TRAIN_76811.png
#   inflating: train/TRAIN_76812.png
#   inflating: train/TRAIN_76813.png
#   inflating: train/TRAIN_76814.png
#   inflating: train/TRAIN_76815.png
#   inflating: train/TRAIN_76816.png
#   inflating: train/TRAIN_76817.png
#   inflating: train/TRAIN_76818.png
#   inflating: train/TRAIN_76819.png
#   inflating: train/TRAIN_76820.png
#   inflating: train/TRAIN_76821.png
#   inflating: train/TRAIN_76822.png
#   inflating: train/TRAIN_76823.png
#   inflating: train/TRAIN_76824.png
#   inflating: train/TRAIN_76825.png
#   inflating: train/TRAIN_76826.png
#   inflating: train/TRAIN_76827.png
#   inflating: train/TRAIN_76828.png
#   inflating: train/TRAIN_76829.png
#   inflating: train/TRAIN_76830.png
#   inflating: train/TRAIN_76831.png
#   inflating: train/TRAIN_76832.png
#   inflating: train/TRAIN_76833.png
#   inflating: train/TRAIN_76834.png
#   inflating: train/TRAIN_76835.png
#   inflating: train/TRAIN_76836.png
#   inflating: train/TRAIN_76837.png
#   inflating: train/TRAIN_76838.png
#   inflating: train/TRAIN_76839.png
#   inflating: train/TRAIN_76840.png
#   inflating: train/TRAIN_76841.png
#   inflating: train/TRAIN_76842.png
#   inflating: train/TRAIN_76843.png
#   inflating: train/TRAIN_76844.png
#   inflating: train/TRAIN_76845.png
#   inflating: train/TRAIN_76846.png
#   inflating: train/TRAIN_76847.png
#   inflating: train/TRAIN_76848.png
#   inflating: train/TRAIN_76849.png
#   inflating: train/TRAIN_76850.png
#   inflating: train/TRAIN_76851.png
#   inflating: train/TRAIN_76852.png
#   inflating: train/TRAIN_76853.png
#   inflating: train/TRAIN_76854.png
#   inflating: train/TRAIN_76855.png
#   inflating: train/TRAIN_76856.png
#   inflating: train/TRAIN_76857.png
#   inflating: train/TRAIN_76858.png
#   inflating: train/TRAIN_76859.png
#   inflating: train/TRAIN_76860.png
#   inflating: train/TRAIN_76861.png
#   inflating: train/TRAIN_76862.png
#   inflating: train/TRAIN_76863.png
#   inflating: train/TRAIN_76864.png
#   inflating: train/TRAIN_76865.png
#   inflating: train/TRAIN_76866.png
#   inflating: train/TRAIN_76867.png
#   inflating: train/TRAIN_76868.png
#   inflating: train/TRAIN_76869.png
#   inflating: train/TRAIN_76870.png
#   inflating: train/TRAIN_76871.png
#   inflating: train/TRAIN_76872.png
#   inflating: train/TRAIN_76873.png
#   inflating: train/TRAIN_76874.png
#   inflating: train/TRAIN_76875.png
#   inflating: train/TRAIN_76876.png
#   inflating: train/TRAIN_76877.png
#   inflating: train/TRAIN_76878.png
#   inflating: train/TRAIN_76879.png
#   inflating: train/TRAIN_76880.png
#   inflating: train/TRAIN_76881.png
#   inflating: train/TRAIN_76882.png
#   inflating: train/TRAIN_76883.png
#   inflating: train/TRAIN_76884.png
#   inflating: train/TRAIN_76885.png
#   inflating: train/TRAIN_76886.png
#   inflating: train/TRAIN_76887.png

# %% [markdown]
# ## 시드값 고정
#
# 아래와 같이 시드값을 고정해야지 매번 학습할 때 마다 동일한 결과를 얻을 수 있다. 시드 값은 하고 싶은 숫자를 하면 되고 저는 생일로 하였습니다 😊.

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(428)

# %% [markdown]
# ## 학습 데이터를 불러옴
#
# 수정

# %%
train_df = pd.read_csv('train.csv')

# %%
test_df = pd.read_csv('test.csv')

# %%
# 학습 데이터로부터 단어 사전(Vocabulary) 구축
train_gt = [gt for gt in train_df['label']]
train_gt = "".join(train_gt)
letters = sorted(list(set(list(train_gt))))
print(len(letters))
# Out:
# 2349

# %%
vocabulary = ["-"] + letters
print(len(vocabulary))
idx2char = {k:v for k,v in enumerate(vocabulary, start=0)}
char2idx = {v:k for k,v in idx2char.items()}
# Out:
# 2350

# %%
train_df.head()
# Out:
#             id                 img_path label
# 0  TRAIN_00000  ./train/TRAIN_00000.png   빨간색
# 1  TRAIN_00001  ./train/TRAIN_00001.png     머
# 2  TRAIN_00002  ./train/TRAIN_00002.png    차차
# 3  TRAIN_00003  ./train/TRAIN_00003.png     써
# 4  TRAIN_00004  ./train/TRAIN_00004.png   놓치다

# %%
train_df['label_len'] = train_df['label'].apply(lambda x: len(x))

# %%
train_df.head()
# Out:
#             id                 img_path label  label_len
# 0  TRAIN_00000  ./train/TRAIN_00000.png   빨간색          3
# 1  TRAIN_00001  ./train/TRAIN_00001.png     머          1
# 2  TRAIN_00002  ./train/TRAIN_00002.png    차차          2
# 3  TRAIN_00003  ./train/TRAIN_00003.png     써          1
# 4  TRAIN_00004  ./train/TRAIN_00004.png   놓치다          3

# %%
import torchmetrics

# %%
from torch.nn.utils.rnn import pad_sequence

transform_train = A.Compose(
    [
        # A.RandomResizedCrop(
        #     height=128, 
        #     width=256, 
        #     scale=(0.24, 0.26),
        #     ratio=(0.90, 1.10),
        #     always_apply=True
        #     ),
        A.Resize(128, 256),
        A.VerticalFlip(p=0.1),
        albumentations.OneOf([
                            albumentations.MotionBlur(p=0.1),
                            albumentations.OpticalDistortion(p=0.3),
                            albumentations.GaussNoise(p=0.5)                 
        ], p=0.8),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        A.pytorch.transforms.ToTensorV2()
        ])

transform_test = A.Compose(
    [
        A.Resize(128, 256),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        A.pytorch.transforms.ToTensorV2()
        ])

"""
    지금에서야 깨달음
    Collator로 넘어오기 전에 Dataset에서 처리가 다 끝나고 batch_size 만큼
    리스트로해서 Collator에게 넘겨주네 ...
    그러니 DataLoader에서 너가 선택한 batch_size 만큼 수정을 해줘야함.
"""
class TextCollator():
    def __init__(self, is_train = False):
        self.is_train = is_train
    
    def __call__(self, samples):
        if self.is_train:
            return_image = []
            return_label = []
            for i in range(len(samples)):
                image, label = samples[i]
                return_image.append(image.unsqueeze(0))
                return_label.append(torch.LongTensor([char2idx[x] for x in label] + [2]))
            return_image = torch.vstack(return_image)
            return_label = pad_sequence(return_label, batch_first = True)
            return_label = torch.LongTensor(return_label)
            return return_image, return_label
        else:
            return_image = []
            for i in range(len(samples)):
                image = samples[i]
                return_image.append(image.unsqueeze(0))
            return_image = torch.vstack(return_image)
            return return_image

class TextDataset(Dataset):
    def __init__(self, images, labels = None, is_train = False, is_valid = False):
        self.images = images
        self.labels = labels
        self.is_train = is_train
        self.is_valid = is_valid
    def __len__(self):
        return len(self.images)

    """
        is_train : 학습에서는 이미지 변경을 수행해주는 작업이 필요하기 때문에
        학습 중이라는 별도의 표시가 필요함
        is_valid : 학습에서는 이미지 변경이 필요하지만 검증에서는 불필요 하기
        때문에 별도로 빼서 진행
    """
    def __getitem__(self, idx):
        image_path = self.images[idx]
        if self.is_train or self.is_valid:
            label = self.labels[idx]
        temp = Image.open(image_path).convert("RGB")
        image = np.array(temp).copy()
        temp.close()

        if self.is_train:
            # 학습 데이터
            transformed = transform_train(image = image)
            image = transformed['image']
            return (image, label)
        elif self.is_valid:
            # 검증 데이터 
            transformed = transform_test(image = image)
            image = transformed['image']
            return (image, label)
        else:
            # 테스트 데이터
            transformed = transform_test(image = image)
            image = transformed['image']
            return image

# %%
config = {
    'n_splits' : 5,
    'random_seed' : 428,
    'batch_size' : 256,
    'input_size' : 1024,
    'hidden_size' : 1024,
    'num_layers' : 1,
    'dropout' : 0.1,
    'model' : 'regnetx_032',
    'vocabulary_len' : len(vocabulary),
    'accumulate_grad_batches' : 1,
    'patience' : 40,
    'max_epochs' : 300
}

# %%
# eff = timm.create_model(config['model'], pretrained=True)
# # CNN Feature Extract
# eff = list(eff.children())[:-2]
# feature_extract = nn.Sequential(
#     *eff
# )
# train_dataset = TextDataset(train_df['img_path'].reset_index(drop=True), train_df['label'].reset_index(drop=True), is_train = True)
# images, labels = train_dataset[0]
# feature_extract(images.unsqueeze(0)).shape

# %%
# assert False

# %%
from pytorch_lightning.accelerators import accelerator
class OCRModel(pl.LightningModule):
    def __init__(self, config):
        # Regnetx_006 -> torch.Size([1, 528, 4, 8]) [:-2]
        # Regnetx_032 -> torch.Size([1, 1008, 4, 8]) [:-2]
        # Effnet -> # torch.Size([2, 512, 4, 8]) [:-4]
        super().__init__()
        self.config = config
        eff =  timm.create_model(config['model'], pretrained=True)
        self.eff_feature_extract = nn.Sequential(*list(eff.children())[:-2]) 
        self.eff_linear = nn.Sequential(
            # nn.BatchNorm1d(8),
            nn.Linear(1008 * 4, 1024, bias = False),
            # nn.BatchNorm1d(8),
        )
        # -> batch_size x 7 x (640 * 2)
        
        self.lstm = nn.LSTM(input_size = config['input_size'], # input_size = 512
                            hidden_size = config['hidden_size'], #  hiddden_size = 512
                            num_layers = config['num_layers'],  # num_laters 
                            dropout = config['dropout'], # dropout
                            bidirectional = True,
                            batch_first = True)
        
        self.lstm_linear = nn.Linear(config['hidden_size']*2, config['vocabulary_len'])

        loss_weight = torch.ones(config['vocabulary_len'])
        loss_weight[0] = 0

        self.crit = nn.CrossEntropyLoss(
            weight = loss_weight
        )
        self.criterion = nn.CTCLoss(blank=0) # idx 0 : -

    def forward(self, x):
        images = x

        representation = self.eff_feature_extract(images)
        # |representation| = (batch_size, 640, 2, 7) = (batch_size, channel, height, width)
        representation = representation.permute(0, 3, 1, 2)
        representation = rearrange(representation, 'b w c h -> b w (c h)')
        # |representation| = (batch_size, 7, 1280) = (batch_size, width, (channel * height))
        representation = self.eff_linear(representation)
        # |representation| = (batch_size, 7, 512)

        context, _ = self.lstm(representation)
        # |conext| = (batch_size, 7, 512 * 2)
        context = self.lstm_linear(context)
        # |context| = (batch_size, 7, vocabulary_len)

        context = rearrange(context, 'b t v -> t b v')

        return context

    # 샘플 별 추론결과를 독립적으로 후처리
    def remove_duplicates(self, text):
        if len(text) > 1:
            letters = [text[0]] + [letter for idx, letter in enumerate(text[1:], start=1) if text[idx] != text[idx-1]]
        elif len(text) == 1:
            letters = [text[0]]
        else:
            return ""
        return "".join(letters)

    def correct_prediction(self, word):
        parts = word.split("-")
        parts = [self.remove_duplicates(part) for part in parts]
        corrected_word = "".join(parts)
        return corrected_word

    def get_acc(self, text_batch_logits, labels):
        # acc구할 차례
        text_batch_logits = text_batch_logits.permute(1, 0, 2)
        text_batch_logits_argmax = text_batch_logits.argmax(dim = -1)
        # |text_batch_logits_argmax| = (batch_size, T)

        text_batch_tokens_new = []
        for text_tokens in text_batch_logits_argmax:
            text = [idx2char[int(idx)] for idx in text_tokens]
            text = "".join(text)
            text_batch_tokens_new.append(text)

        temp = pd.DataFrame(text_batch_tokens_new, columns = ['label'])
        temp['label'] = temp['label'].apply(self.correct_prediction)

        # print(temp['label'][:10], labels[:10])
        acc = accuracy_score(temp['label'].values, labels)
        
        del temp
        gc.collect()

        return acc

    def encode_text_batch(self, text_batch):
        text_batch_targets_lens = [len(text) for text in text_batch]
        text_batch_targets_lens = torch.IntTensor(text_batch_targets_lens)

        text_batch_concat = "".join(text_batch)
        text_batch_targets = [char2idx[c] for c in text_batch_concat]
        text_batch_targets = torch.IntTensor(text_batch_targets)
        
        return text_batch_targets, text_batch_targets_lens

    def compute_loss(self, text_batch, text_batch_logits): # labels, context
        """
        text_batch: list of strings of length equal to batch size
        text_batch_logits: Tensor of size([T, batch_size, num_classes])
        """
        text_batch_logps = F.log_softmax(text_batch_logits, 2) # [T, batch_size, num_classes]  
        text_batch_logps_lens = torch.full(size=(text_batch_logps.size(1),), 
                                        fill_value=text_batch_logps.size(0), 
                                        dtype=torch.int32).to(text_batch_logits.device) # [batch_size] 

        text_batch_targets, text_batch_targets_lens = self.encode_text_batch(text_batch)

        loss = self.criterion(text_batch_logps, text_batch_targets, text_batch_logps_lens, text_batch_targets_lens)

        # acc구할 차례
        acc = self.get_acc(text_batch_logits, text_batch)

        return loss, acc

    def training_step(self, batch, batch_idx):
        # batch = (image, label)
        # |image| = (batch_size, channel, h, w)
        # |label| = ("안녕하세요", "나는") <- tuple 형태로 담겨져 있음
        images, labels = batch

        representation = self.eff_feature_extract(images)
        # |representation| = (batch_size, 512, 4, 8) = (batch_size, channel, height, width)
        representation = representation.permute(0, 3, 1, 2)
        representation = rearrange(representation, 'b w c h -> b w (c h)')
        # |representation| = (batch_size, 8, 512*4) = (batch_size, width, (channel * height))
        representation = self.eff_linear(representation)
        # |representation| = (batch_size, 8, 512)

        context, _ = self.lstm(representation)
        # |conext| = (batch_size, 7, 512 * 2)
        context = self.lstm_linear(context)
        # |context| = (batch_size, 7, vocabulary_len)

        context = rearrange(context, 'b t v -> t b v')
        
        loss, acc = self.compute_loss(labels, context)


        metrics = {'train_loss':loss, 'train_acc':acc}
        self.log_dict(metrics, prog_bar=True)
        return {
            "loss":loss
        }

    def validation_step(self, batch, batch_idx):
        # batch = (image, label)
        # |image| = (batch_size, channel, h, w)
        # |label| = (batch_size, length) 여기서 length의 최대 길이를 7로 설정함 
        images, labels = batch

        representation = self.eff_feature_extract(images)
        # |representation| = (batch_size, 640, 2, 7) = (batch_size, channel, height, width)
        representation = representation.permute(0, 3, 1, 2)
        representation = rearrange(representation, 'b w c h -> b w (c h)')
        # |representation| = (batch_size, 7, 1280) = (batch_size, width, (channel * height))
        representation = self.eff_linear(representation)
        # |representation| = (batch_size, 7, 512)

        context, _ = self.lstm(representation)
        # |conext| = (batch_size, 7, 512 * 2)
        context = self.lstm_linear(context)
        # |context| = (batch_size, 7, vocabulary_len)

        context = rearrange(context, 'b t v -> t b v')
        
        loss, acc = self.compute_loss(labels, context)


        metrics = {'val_loss':loss, 'val_acc': acc}
        self.log_dict(metrics, prog_bar=True)
        return {
            "loss":loss
        }

    def test_step(self, batch, batch_idx):
        pass
    
    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        images = batch

        representation = self.eff_feature_extract(images)
        # |representation| = (batch_size, 640, 2, 7) = (batch_size, channel, height, width)
        representation = representation.permute(0, 3, 1, 2)
        representation = rearrange(representation, 'b w c h -> b w (c h)')
        # |representation| = (batch_size, 7, 1280) = (batch_size, width, (channel * height))
        representation = self.eff_linear(representation)
        # |representation| = (batch_size, 7, 512)

        context, _ = self.lstm(representation)
        # |conext| = (batch_size, 7, 512 * 2)
        context = self.lstm_linear(context)
        # |context| = (batch_size, 7, vocabulary_len)

        context = rearrange(context, 'b t v -> t b v')

        return context

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-4)
        return optimizer

# %%
test_dataset = TextDataset(test_df['img_path'].reset_index(drop=True))
test_dataloader = DataLoader(test_dataset, batch_size = config['batch_size'])

# %%
temp = torch.load("/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=13-step=4214-train_loss=0.0656-train_acc=0.9886.ckpt")
m = OCRModel(config)
m.load_state_dict(temp['state_dict'])
trainer = pl.Trainer(accelerator="gpu")
p = trainer.predict(m, test_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]

# %%
p_cat = torch.cat(p, dim = 1)

# %%
p_cat.shape
# Out:
# torch.Size([8, 74121, 2350])

# %%
# 샘플 별 추론결과를 독립적으로 후처리
def remove_duplicates(text):
    if len(text) > 1:
        letters = [text[0]] + [letter for idx, letter in enumerate(text[1:], start=1) if text[idx] != text[idx-1]]
    elif len(text) == 1:
        letters = [text[0]]
    else:
        return ""
    return "".join(letters)

def correct_prediction(word):
    parts = word.split("-")
    parts = [remove_duplicates(part) for part in parts]
    corrected_word = "".join(parts)
    return corrected_word

# %%
# acc구할 차례
text_batch_logits = p_cat.permute(1, 0, 2)
text_batch_logits_argmax = text_batch_logits.argmax(dim = -1)

text_batch_tokens_new = []
for text_tokens in text_batch_logits_argmax:
    text = [idx2char[int(idx)] for idx in text_tokens]
    text = "".join(text)
    text_batch_tokens_new.append(text)

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['label'] = text_batch_tokens_new

# %%
submit['label'] = submit['label'].apply(correct_prediction)

# %%
submit['label']
# Out:
# 0           남말
# 1           상랑
# 2        받아들이다
# 3          바구니
# 4            살
#          ...
# 74116      캐나다
# 74117       사무
# 74118     친절하다
# 74119        쪽
# 74120     부정하다
# Name: label, Length: 74121, dtype: object

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/submission3.csv', index=False)

# %%
def get_acc(self, text_batch_logits, labels):
    # acc구할 차례
    text_batch_logits = text_batch_logits.permute(1, 0, 2)
    text_batch_logits_argmax = text_batch_logits.argmax(dim = -1)
    # |text_batch_logits_argmax| = (batch_size, T)

    text_batch_tokens_new = []
    for text_tokens in text_batch_logits_argmax:
        text = [idx2char[int(idx)] for idx in text_tokens]
        text = "".join(text)
        text_batch_tokens_new.append(text)

    temp = pd.DataFrame(text_batch_tokens_new, columns = ['label'])
    temp['label'] = temp['label'].apply(self.correct_prediction)

# %% [markdown]
# ## loc으로 꺼내온 데이터 에는 reset_index를 해줘야함
#
# reset_index 해줘야 하는거 모르고 개고생했네 ....

# %%
from pytorch_lightning.callbacks import RichProgressBar, EarlyStopping, ModelCheckpoint

train_dataset = TextDataset(train_df['img_path'].reset_index(drop=True), train_df['label'].reset_index(drop=True), is_train = True)
train_dataloader = DataLoader(train_dataset, batch_size = config['batch_size'], shuffle = True)

dirpath = f"/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold"
checkpoint_callback = ModelCheckpoint(
dirpath=dirpath,
save_last = True,
save_top_k =-1,
filename='{epoch}-{step}-{train_loss:.4f}-{train_acc:.4f}',
verbose=True,
monitor='train_acc',
mode='max'
)

model = OCRModel(config)
trainer = pl.Trainer(max_epochs = config['max_epochs'], accelerator="gpu", accumulate_grad_batches = config['accumulate_grad_batches'], precision=16,
                        callbacks=[EarlyStopping('train_acc', patience = config['patience'], mode='max', verbose = True), checkpoint_callback])

trainer.fit(model, train_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit native Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                | Type             | Params
# ---------------------------------------------------------
# 0 | eff_feature_extract | Sequential       | 14.3 M
# 1 | eff_linear          | Sequential       | 4.1 M
# 2 | lstm                | LSTM             | 16.8 M
# 3 | lstm_linear         | Linear           | 4.8 M
# 4 | crit                | CrossEntropyLoss | 0
# 5 | criterion           | CTCLoss          | 0
# ---------------------------------------------------------
# 40.0 M    Trainable params
# 0         Non-trainable params
# 40.0 M    Total params
# 80.050    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved. New best score: 0.011
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 0, global step 301: 'train_acc' reached 0.01136 (best 0.01136), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=0-step=301-train_loss=5.3249-train_acc=0.0114.ckpt' as top 1
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.068 >= min_delta = 0.0. New best score: 0.080
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 1, global step 602: 'train_acc' reached 0.07955 (best 0.07955), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=1-step=602-train_loss=3.7806-train_acc=0.0795.ckpt' as top 2
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.193 >= min_delta = 0.0. New best score: 0.273
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 2, global step 903: 'train_acc' reached 0.27273 (best 0.27273), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=2-step=903-train_loss=2.2352-train_acc=0.2727.ckpt' as top 3
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.330 >= min_delta = 0.0. New best score: 0.602
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 3, global step 1204: 'train_acc' reached 0.60227 (best 0.60227), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=3-step=1204-train_loss=1.2841-train_acc=0.6023.ckpt' as top 4
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.102 >= min_delta = 0.0. New best score: 0.705
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 4, global step 1505: 'train_acc' reached 0.70455 (best 0.70455), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=4-step=1505-train_loss=0.9243-train_acc=0.7045.ckpt' as top 5
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.170 >= min_delta = 0.0. New best score: 0.875
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 5, global step 1806: 'train_acc' reached 0.87500 (best 0.87500), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=5-step=1806-train_loss=0.5554-train_acc=0.8750.ckpt' as top 6
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.011 >= min_delta = 0.0. New best score: 0.886
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 6, global step 2107: 'train_acc' reached 0.88636 (best 0.88636), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=6-step=2107-train_loss=0.3505-train_acc=0.8864.ckpt' as top 7
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.023 >= min_delta = 0.0. New best score: 0.909
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 7, global step 2408: 'train_acc' reached 0.90909 (best 0.90909), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=7-step=2408-train_loss=0.3052-train_acc=0.9091.ckpt' as top 8
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 8, global step 2709: 'train_acc' reached 0.90909 (best 0.90909), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=8-step=2709-train_loss=0.2330-train_acc=0.9091.ckpt' as top 9
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.045 >= min_delta = 0.0. New best score: 0.955
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 9, global step 3010: 'train_acc' reached 0.95455 (best 0.95455), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=9-step=3010-train_loss=0.1404-train_acc=0.9545.ckpt' as top 10
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 10, global step 3311: 'train_acc' reached 0.95455 (best 0.95455), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=10-step=3311-train_loss=0.1274-train_acc=0.9545.ckpt' as top 11
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.023 >= min_delta = 0.0. New best score: 0.977
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 11, global step 3612: 'train_acc' reached 0.97727 (best 0.97727), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=11-step=3612-train_loss=0.0905-train_acc=0.9773.ckpt' as top 12
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 12, global step 3913: 'train_acc' reached 0.95455 (best 0.97727), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=12-step=3913-train_loss=0.0914-train_acc=0.9545.ckpt' as top 13
# INFO:pytorch_lightning.callbacks.early_stopping:Metric train_acc improved by 0.011 >= min_delta = 0.0. New best score: 0.989
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 13, global step 4214: 'train_acc' reached 0.98864 (best 0.98864), saving model to '/content/drive/MyDrive/Colab Notebooks/DACON/2023_교원그룹_AI_챌린지/NoFold/epoch=13-step=4214-train_loss=0.0656-train_acc=0.9886.ckpt' as top 14
